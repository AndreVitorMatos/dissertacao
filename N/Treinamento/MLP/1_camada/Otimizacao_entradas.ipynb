# %% [markdown]
# # Otimização do modelo MLP para 1 camada para o subsistema N

# %% [markdown]
# ## Importar bibliotecas

# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

import pandas as pd
import numpy as np

import random
from itertools import product

import pickle

# %%
subsistema = 'N'

# %% [markdown]
# ## Importando dados

# %%
dados_treinamento = pd.read_csv(f'../../../Preprocessamento/{subsistema}_treinamento.csv', index_col='DataHora')
dados_treinamento.index = pd.to_datetime(dados_treinamento.index, format="%Y-%m-%d %H:%M:%S")
dados_treinamento
# Out:
#                         Carga  Temperatura  seg  ter  qua  qui  sex  sab  dom  \
# DataHora
# 2018-01-03 00:00:00 -0.463425    -0.226717    0    0    1    0    0    0    0
# 2018-01-03 01:00:00 -0.473038    -0.226717    0    0    1    0    0    0    0
# 2018-01-03 02:00:00 -0.511504    -0.258305    0    0    1    0    0    0    0
# 2018-01-03 03:00:00 -0.536532    -0.287854    0    0    1    0    0    0    0
# 2018-01-03 04:00:00 -0.560466    -0.301101    0    0    1    0    0    0    0
# ...                       ...          ...  ...  ...  ...  ...  ...  ...  ...
# 2023-12-31 19:00:00 -0.307824    -0.153352    0    0    0    0    0    0    1
# 2023-12-31 20:00:00 -0.199531    -0.151314    0    0    0    0    0    0    1
# 2023-12-31 21:00:00 -0.184359    -0.196148    0    0    0    0    0    0    1
# 2023-12-31 22:00:00 -0.158424    -0.164561    0    0    0    0    0    0    1
# 2023-12-31 23:00:00 -0.133254    -0.194110    0    0    0    0    0    0    1
#
#                      seno_dia_semana  ...  mai  jun  jul  ago  set  out  nov  \
# DataHora                              ...
# 2018-01-03 00:00:00         0.974928  ...    0    0    0    0    0    0    0
# 2018-01-03 01:00:00         0.974928  ...    0    0    0    0    0    0    0
# 2018-01-03 02:00:00         0.974928  ...    0    0    0    0    0    0    0
# 2018-01-03 03:00:00         0.974928  ...    0    0    0    0    0    0    0
# 2018-01-03 04:00:00         0.974928  ...    0    0    0    0    0    0    0
# ...                              ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2023-12-31 19:00:00        -0.781831  ...    0    0    0    0    0    0    0
# 2023-12-31 20:00:00        -0.781831  ...    0    0    0    0    0    0    0
# 2023-12-31 21:00:00        -0.781831  ...    0    0    0    0    0    0    0
# 2023-12-31 22:00:00        -0.781831  ...    0    0    0    0    0    0    0
# 2023-12-31 23:00:00        -0.781831  ...    0    0    0    0    0    0    0
#
#                      dez      seno_mes  cosseno_mes
# DataHora
# 2018-01-03 00:00:00    0  5.000000e-01     0.866025
# 2018-01-03 01:00:00    0  5.000000e-01     0.866025
# 2018-01-03 02:00:00    0  5.000000e-01     0.866025
# 2018-01-03 03:00:00    0  5.000000e-01     0.866025
# 2018-01-03 04:00:00    0  5.000000e-01     0.866025
# ...                  ...           ...          ...
# 2023-12-31 19:00:00    1 -2.449294e-16     1.000000
# 2023-12-31 20:00:00    1 -2.449294e-16     1.000000
# 2023-12-31 21:00:00    1 -2.449294e-16     1.000000
# 2023-12-31 22:00:00    1 -2.449294e-16     1.000000
# 2023-12-31 23:00:00    1 -2.449294e-16     1.000000
#
# [52536 rows x 25 columns]

# %%
dados_treinamento_2019 = dados_treinamento[dados_treinamento.index.year != 2018]
dados_treinamento_2020 = dados_treinamento_2019[dados_treinamento_2019.index.year != 2019]
dados_treinamento_2021 = dados_treinamento_2020[dados_treinamento_2020.index.year != 2020]
dados_treinamento_2022 = dados_treinamento_2021[dados_treinamento_2021.index.year != 2021]
dados_treinamento_2023 = dados_treinamento_2022[dados_treinamento_2022.index.year != 2022]

# %%
dados_validacao = pd.read_csv(f'../../../Preprocessamento/{subsistema}_validacao.csv', index_col='DataHora')
dados_validacao.index = pd.to_datetime(dados_validacao.index, format="%Y-%m-%d %H:%M:%S")
dados_validacao
# Out:
#                         Carga  Temperatura  seg  ter  qua  qui  sex  sab  dom  \
# DataHora
# 2023-12-30 00:00:00 -0.000783    -0.185959    0    0    0    0    0    1    0
# 2023-12-30 01:00:00 -0.011805    -0.170675    0    0    0    0    0    1    0
# 2023-12-30 02:00:00 -0.026000    -0.183921    0    0    0    0    0    1    0
# 2023-12-30 03:00:00 -0.060026    -0.183921    0    0    0    0    0    1    0
# 2023-12-30 04:00:00 -0.094685    -0.183921    0    0    0    0    0    1    0
# ...                       ...          ...  ...  ...  ...  ...  ...  ...  ...
# 2024-12-31 19:00:00  0.071314    -0.045343    0    1    0    0    0    0    0
# 2024-12-31 20:00:00  0.050805    -0.106481    0    1    0    0    0    0    0
# 2024-12-31 21:00:00  0.090677    -0.138068    0    1    0    0    0    0    0
# 2024-12-31 22:00:00  0.112857    -0.167618    0    1    0    0    0    0    0
# 2024-12-31 23:00:00  0.142469    -0.167618    0    1    0    0    0    0    0
#
#                      seno_dia_semana  ...  mai  jun  jul  ago  set  out  nov  \
# DataHora                              ...
# 2023-12-30 00:00:00        -0.974928  ...    0    0    0    0    0    0    0
# 2023-12-30 01:00:00        -0.974928  ...    0    0    0    0    0    0    0
# 2023-12-30 02:00:00        -0.974928  ...    0    0    0    0    0    0    0
# 2023-12-30 03:00:00        -0.974928  ...    0    0    0    0    0    0    0
# 2023-12-30 04:00:00        -0.974928  ...    0    0    0    0    0    0    0
# ...                              ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2024-12-31 19:00:00         0.781831  ...    0    0    0    0    0    0    0
# 2024-12-31 20:00:00         0.781831  ...    0    0    0    0    0    0    0
# 2024-12-31 21:00:00         0.781831  ...    0    0    0    0    0    0    0
# 2024-12-31 22:00:00         0.781831  ...    0    0    0    0    0    0    0
# 2024-12-31 23:00:00         0.781831  ...    0    0    0    0    0    0    0
#
#                      dez      seno_mes  cosseno_mes
# DataHora
# 2023-12-30 00:00:00    1 -2.449294e-16          1.0
# 2023-12-30 01:00:00    1 -2.449294e-16          1.0
# 2023-12-30 02:00:00    1 -2.449294e-16          1.0
# 2023-12-30 03:00:00    1 -2.449294e-16          1.0
# 2023-12-30 04:00:00    1 -2.449294e-16          1.0
# ...                  ...           ...          ...
# 2024-12-31 19:00:00    1 -2.449294e-16          1.0
# 2024-12-31 20:00:00    1 -2.449294e-16          1.0
# 2024-12-31 21:00:00    1 -2.449294e-16          1.0
# 2024-12-31 22:00:00    1 -2.449294e-16          1.0
# 2024-12-31 23:00:00    1 -2.449294e-16          1.0
#
# [8832 rows x 25 columns]

# %% [markdown]
# ## Criação dos Datasets

# %%
class Dados(Dataset):
    def __init__(self, dados, modelo, entrada_carga = 48, horas_de_previsao = 24, horizonte = 2):
        # Recebendo e tratando os dados
        self.dados = dados

        # Pega dados de carga
        self.carga = self.dados['Carga']

        # Pega dados de temperatura
        self.temperatura = self.dados['Temperatura']
        
        # Pega dados de dia da semana no formato sen cos
        self.lista_dias_semana_S = list(self.dados.columns[2:4])
        self.dias_semana_S = self.dados[self.lista_dias_semana_S]

        # Pega dados de mes no formato sen cos
        self.lista_mes_S = list(self.dados.columns[4:])
        self.meses_S = self.dados[self.lista_mes_S]

        # Configurando outras variaveis
        self.entrada_carga = 48
        self.horas_de_previsao = horas_de_previsao
        self.horizonte = horizonte

        # Separa os dados
        self.entrada = []
        self.previsao = []
        for idx in range((len(self.carga) // 24) - self.entrada_carga // 24 - self.horizonte + 1):
            # Pula dia a dia
            idx = idx * 24
            
            # Salva o historico de carga
            carga_hist = self.carga[idx: idx + self.entrada_carga]

            # Salva os dados de temperatura do dia da previsão
            temperatura_H = self.temperatura[idx + self.entrada_carga + (self.horizonte - 1) * 24 : idx + self.entrada_carga + (self.horizonte) * 24]

            # Salva os dados de temperatura mínima, media e máxima
            temperatura_P = pd.Series([temperatura_H.min(), temperatura_H.mean(), temperatura_H.max()])
            
            # Salva os dados de dia da semana no formato sen cos
            dia_S = self.dias_semana_S.iloc[idx + self.entrada_carga + (self.horizonte - 1) * 24]

            # Salva os dados de mes no formato sen cos
            mes_S = self.meses_S.iloc[idx + self.entrada_carga + (self.horizonte - 1) * 24]

            # Gera as entradas concatenando os dados
            if modelo == 'M1_1':
                previsor_concat = pd.concat([carga_hist]).values
            elif modelo == 'M2_1':
                previsor_concat = pd.concat([carga_hist, temperatura_H]).values
            elif modelo == 'M2_2':
                previsor_concat = pd.concat([carga_hist, temperatura_P]).values
            elif modelo == 'M2_3':
                previsor_concat = pd.concat([carga_hist, dia_S]).values
            elif modelo == 'M2_4':
                previsor_concat = pd.concat([carga_hist, mes_S]).values
            elif modelo == 'M3_1':
                previsor_concat = pd.concat([carga_hist, temperatura_H, dia_S]).values
            elif modelo == 'M3_2':
                previsor_concat = pd.concat([carga_hist, temperatura_H, mes_S]).values
            elif modelo == 'M3_3':
                previsor_concat = pd.concat([carga_hist, temperatura_P, dia_S]).values
            elif modelo == 'M3_4':
                previsor_concat = pd.concat([carga_hist, temperatura_P, mes_S]).values
            elif modelo == 'M3_5':
                previsor_concat = pd.concat([carga_hist, dia_S, mes_S]).values
            elif modelo == 'M4_1':
                previsor_concat = pd.concat([carga_hist, temperatura_H, dia_S, mes_S]).values
            elif modelo == 'M4_2':
                previsor_concat = pd.concat([carga_hist, temperatura_P, dia_S, mes_S]).values
                
            self.entrada.append(previsor_concat)

            # Gera os dados de saida
            saida_carga = self.carga[idx + self.entrada_carga + (self.horizonte - 1) * 24 : idx + self.entrada_carga + (self.horizonte) * 24]
            self.previsao.append(saida_carga)
            
        self.entrada = torch.tensor(np.array(self.entrada), dtype = torch.float32)
        self.previsao = torch.tensor(np.array(self.previsao), dtype = torch.float32)

    def __len__(self):
        return (len(self.carga) // 24) - self.entrada_carga // 24 - self.horizonte + 1

    def __getitem__(self, idx):
        return self.entrada[idx], self.previsao[idx]

# %% [markdown]
# ## Criando modelo MLP e earlystop

# %%
class MLP(nn.Module):
    def __init__(self, n_entrada, n_primeira_camada, n_saida):
        super(MLP, self).__init__()

        self.ativacao = nn.Tanh()

        self.features = nn.Sequential(
            nn.Linear(n_entrada, n_primeira_camada),
            self.ativacao,
            nn.Linear(n_primeira_camada, n_saida),
            nn.Tanh(),
        )
    
    def forward(self, X):
        
        saida = self.features(X)

        return saida

# %%
class EarlyStopping:
    def __init__(self, patience=25, min_epoch = 100):
        """
        patience: quantas épocas esperar antes de parar se não houver melhora
        """
        self.patience = patience
        self.best_loss = np.inf
        self.counter = 0
        self.min_epoch = min_epoch
        self.contador_epocas = 0

    def __call__(self, val_loss):
        self.contador_epocas += 1
        if val_loss < self.best_loss:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience and self.contador_epocas >= self.min_epoch:
                return True  # Sinaliza que o treinamento deve parar
            return False

# %% [markdown]
# ## Criando treinamento e validação

# %%
def treinamento(rede, treinamento_dataloader, validacao_dataloader, otimizador, criterio):  
    rede.train()
    perda_treino = []
    for entrada, saida in treinamento_dataloader:
        otimizador.zero_grad()
        previsao = rede(entrada)
        perda = criterio(previsao, saida)
        perda_treino.append(perda.item())
        perda.backward()
        otimizador.step()
        

    # Validação
    rede.eval()
    perda_validacao = []
    with torch.no_grad():
        for entrada, saida in validacao_dataloader:
            previsao = rede(entrada)
            perda_validacao.append(criterio(previsao, saida).item())
    
    # Cálculo da média das perdas
    perda_treino = np.asarray(perda_treino)
    perda_validacao = np.asarray(perda_validacao)

    return perda_treino.mean(), perda_validacao.mean()

# %% [markdown]
# ## Função perda

# %%
def treinar(params):
    # Definição dos hiperparâmetros que serão otimizados
    modelo_entrada, n_neuronios, ano_entrada, taxa_aprendizado, otm  = params

    lista_modelo_entrada = (
        [f"M1_{i}" for i in range(1, 2)] +
        [f"M2_{i}" for i in range(1, 5)] +
        [f"M3_{i}" for i in range(1, 6)] + 
        [f"M4_{i}" for i in range(1, 3)]
    )
    lista_modelo_n_entradas = [48, 48+24, 48+3, 48+2, 48+2, 48+24+2, 48+24+2, 48+3+2, 48+3+2, 48+2+2, 48+24+2+2, 48+3+2+2]
    n_entradas = lista_modelo_n_entradas[modelo_entrada]
    modelo_entrada = lista_modelo_entrada[modelo_entrada]

    lista_n_neuronios = [24, round(0.25*(2*n_entradas-24)+24), round(0.5*(2*n_entradas-24)+24), round(0.75*(2*n_entradas-24)+24), 2*n_entradas]
    n_neuronios = lista_n_neuronios[n_neuronios]

    lista_ano_entrada = [2018, 2020, 2022]
    ano_entrada = lista_ano_entrada[ano_entrada]

    lista_taxa_aprendizado = [0.01, 0.001, 0.0001]
    taxa_aprendizado = lista_taxa_aprendizado[taxa_aprendizado]

    lista_otm = ['Adam', 'Rprop', 'RMSprop']
    otm = lista_otm[otm]

    num_seeds = 10
    n_earlystop = 25
    epocas = 1000
    lista_melhor_loss = []

    for seed in range(1, num_seeds + 1):
        # Criando dados
        if ano_entrada == 2018:
            treinamento_dataset = Dados(dados_treinamento, modelo_entrada)
        elif ano_entrada == 2020:
            treinamento_dataset = Dados(dados_treinamento_2020, modelo_entrada)
        elif ano_entrada == 2022:
            treinamento_dataset = Dados(dados_treinamento_2022, modelo_entrada)
        treinamento_dataloader = DataLoader(treinamento_dataset, batch_size=32, shuffle=True)

        validacao_dataset = Dados(dados_validacao, modelo_entrada)
        validacao_dataloader = DataLoader(validacao_dataset, batch_size=32, shuffle=True)

        # Criando redes
        saida = 24
        rede = MLP(n_entradas, n_neuronios, saida)
           
        # Definindo criterio e loss
        criterio = nn.MSELoss()

        if otm == 'Adam':
            otimizador = optim.Adam(rede.parameters(), lr = taxa_aprendizado)
        elif otm == 'Rprop':
            otimizador = optim.Rprop(rede.parameters(), lr = taxa_aprendizado)
        elif otm == 'RMSprop':
            otimizador = optim.RMSprop(rede.parameters(), lr = taxa_aprendizado)
        
        earlystop = EarlyStopping(n_earlystop)
        melhor_perda_validacao = np.inf
        treinamento_losses, validacao_losses = [], []

        for epoca in range(epocas):
            perda_treino, perda_validacao = treinamento(rede, treinamento_dataloader, validacao_dataloader, otimizador, criterio)
            
            treinamento_losses.append(perda_treino)
            validacao_losses.append(perda_validacao)

            if perda_validacao < melhor_perda_validacao:
                melhor_perda_validacao = perda_validacao

            # Early Stopping
            if earlystop(perda_validacao):
                break
        
        lista_melhor_loss.append(melhor_perda_validacao)

    return np.mean(lista_melhor_loss)

# %% [markdown]
# ## Otimização

# %%
class AG:
    def __init__(self, limites, tamanho_populacao, geracoes, taxa_mutacao, funcao_custo):
        self.limites = limites
        self.numero_variaveis = len(self.limites)
        self.tamanho_populacao = tamanho_populacao
        self.geracoes = geracoes
        self.taxa_mutacao = taxa_mutacao
        self.funcao_custo = funcao_custo
        self.geracao_atual = 0

        intervalos = [range(a, b+1) for a, b in limites]
        possibilidades = [comb for comb in product(*intervalos)]
        self.dic_historico = {(possibilidade): [] for possibilidade in possibilidades}

        self.populacao = []

    def criar_individuo(self):
        return [round(random.uniform(a - 0.49, b + 0.49)) for (a, b) in self.limites]

    def criar_populacao(self):
        return [self.criar_individuo() for _ in range(self.tamanho_populacao)]

    def avaliar_fitness(self):
        custos = []
        for ind in self.populacao:
            chave = tuple(ind)
            if self.dic_historico[chave]:
                print(f'Indivíduo já avaliado.')
                custos.append(self.dic_historico[chave][0])
            else:
                fit = self.funcao_custo(ind)
                custos.append(fit)
                self.dic_historico[chave].append(fit)
            print(f'Indivíduo: {ind}. Fit: {custos[-1]}')
        self.fitness = [1 / (1 + c) for c in custos]

    def selecao_roleta(self):
        soma = sum(self.fitness)
        pick = random.uniform(0, soma)
        atual = 0
        for ind, fit in zip(self.populacao, self.fitness):
            atual += fit
            if atual > pick:
                return ind
        return self.populacao[-1]

    def cruzamento(self, pai1, pai2):
        n = len(pai1)
        indices_pai1 = random.sample(range(n), k=n//2)
        filho = [pai1[i] if i in indices_pai1 else pai2[i] for i in range(n)]
        return filho

    def mutacao(self, ind):
        for i in range(self.numero_variaveis):
            if random.random() < self.taxa_mutacao:
                a, b = self.limites[i]
                ind[i] = round(random.uniform(a - 0.49, b + 0.49))
        return ind

    def salvar(self, nome_arquivo='ag_estado.pkl'):
        with open(nome_arquivo, 'wb') as f:
            pickle.dump(self, f)
        print(f"Estado salvo em '{nome_arquivo}'.")

    @staticmethod
    def carregar(nome_arquivo='ag_estado.pkl'):
        with open(nome_arquivo, 'rb') as f:
            ag = pickle.load(f)
        print(f"Estado carregado de '{nome_arquivo}'.")
        return ag

    def algoritmo_genetico(self, continuar=False):
        if not continuar or not self.populacao:
            self.populacao = self.criar_populacao()

        for geracao in range(self.geracao_atual, self.geracoes):
            print(f'\nGeração {geracao + 1}')
            self.avaliar_fitness()

            # Elitismo de 2 melhores
            indices_melhores = sorted(range(len(self.fitness)), key=lambda i: self.fitness[i], reverse=True)[:2]
            elite = [self.populacao[i] for i in indices_melhores]
            nova_pop = elite[:]

            while len(nova_pop) < self.tamanho_populacao:
                pai1 = self.selecao_roleta()
                pai2 = self.selecao_roleta()
                filho = self.cruzamento(pai1, pai2)
                filho = self.mutacao(filho)
                nova_pop.append(filho)

            self.populacao = nova_pop
            print(f"Elite: {elite}")

            # Salvar estado atual
            self.salvar()
            self.geracao_atual += 1

# %% [markdown]
# ### Rodada

# %%
busca_entrada = AG(
    limites = [(0, 11), (0, 4), (0, 2), (0, 2), (0, 2)], 
    tamanho_populacao = 50, 
    geracoes = 10, 
    taxa_mutacao = 0.03, 
    funcao_custo = treinar)

# %%
busca_entrada.algoritmo_genetico()
# Out:
# Geração 1
# Indivíduo: [2, 1, 2, 0, 2]. Fit: 0.007406610134057701
# Indivíduo: [2, 2, 1, 1, 1]. Fit: 0.011091444788811109
# Indivíduo: [2, 3, 2, 2, 2]. Fit: 0.006811730794530983
# Indivíduo: [7, 0, 0, 2, 0]. Fit: 0.004432241402294796
# Indivíduo: [10, 4, 0, 2, 2]. Fit: 0.003680603006311382
# Indivíduo: [4, 0, 2, 0, 1]. Fit: 0.010757560151008268
# Indivíduo: [11, 2, 1, 0, 0]. Fit: 0.0030434508749749515
# Indivíduo: [5, 4, 2, 0, 0]. Fit: 0.0027188917195114003
# Indivíduo: [4, 4, 2, 1, 2]. Fit: 0.006887000826342653
# Indivíduo: [11, 1, 1, 2, 1]. Fit: 0.007218580755094688
# Indivíduo: [2, 4, 1, 1, 1]. Fit: 0.010472400199311475
# Indivíduo já avaliado.
# Indivíduo: [2, 1, 2, 0, 2]. Fit: 0.007406610134057701
# Indivíduo: [4, 0, 0, 2, 1]. Fit: 0.014342554612085223
# Indivíduo: [4, 0, 0, 1, 1]. Fit: 0.014551343861967325
# Indivíduo: [6, 2, 0, 2, 1]. Fit: 0.011265923913257817
# Indivíduo: [11, 2, 2, 0, 2]. Fit: 0.00427819653317177
# Indivíduo: [11, 4, 1, 2, 1]. Fit: 0.006470795315302288
# Indivíduo: [4, 1, 2, 2, 0]. Fit: 0.00773166293123116
# Indivíduo: [4, 2, 1, 1, 1]. Fit: 0.012122677776884907
# Indivíduo: [5, 0, 0, 0, 0]. Fit: 0.0031950263723653435
# Indivíduo: [4, 0, 1, 0, 0]. Fit: 0.006931722581308956
# Indivíduo: [5, 1, 0, 2, 2]. Fit: 0.005069074956312155
# Indivíduo: [1, 2, 0, 2, 1]. Fit: 0.011284729733597487
# Indivíduo: [11, 3, 0, 1, 1]. Fit: 0.0073648779439584675
# Indivíduo: [0, 4, 0, 0, 1]. Fit: 0.012452281829124936
# Indivíduo: [3, 3, 2, 2, 0]. Fit: 0.004969475765634948
# Indivíduo: [10, 3, 1, 0, 0]. Fit: 0.0028254443769886468
# Indivíduo: [10, 4, 1, 0, 0]. Fit: 0.002882710523166073
# Indivíduo: [9, 4, 1, 1, 0]. Fit: 0.0030852427900147934
# Indivíduo: [1, 1, 2, 1, 1]. Fit: 0.010988808050751687
# Indivíduo: [10, 2, 2, 2, 2]. Fit: 0.0037928387008529774
# Indivíduo: [0, 4, 2, 0, 2]. Fit: 0.008073595278741168
# Indivíduo: [7, 0, 0, 1, 0]. Fit: 0.0031473286352896443
# Indivíduo: [4, 2, 0, 1, 0]. Fit: 0.007348232904526715
# Indivíduo: [9, 1, 0, 0, 1]. Fit: 0.008508650745109965
# Indivíduo já avaliado.
# Indivíduo: [1, 1, 2, 1, 1]. Fit: 0.010988808050751687
# Indivíduo: [3, 2, 1, 2, 1]. Fit: 0.007386189547833055
# Indivíduo: [9, 3, 0, 0, 0]. Fit: 0.0033737235624964035
# Indivíduo: [5, 2, 0, 2, 0]. Fit: 0.0033393092880335947
# Indivíduo: [6, 1, 1, 2, 2]. Fit: 0.007221321911007788
# Indivíduo: [8, 0, 0, 1, 0]. Fit: 0.006858926479859898
# Indivíduo: [8, 4, 0, 0, 0]. Fit: 0.006795186353459335
# Indivíduo: [5, 2, 0, 1, 0]. Fit: 0.002777034396422096
# Indivíduo: [0, 4, 1, 2, 2]. Fit: 0.007322228581566984
# Indivíduo: [0, 4, 0, 2, 2]. Fit: 0.007945945602841677
# Indivíduo: [1, 3, 1, 2, 1]. Fit: 0.010832309825733926
# Indivíduo: [2, 1, 0, 2, 2]. Fit: 0.007952978139898429
# Indivíduo: [6, 1, 0, 0, 0]. Fit: 0.006965824135113508
# Indivíduo: [3, 3, 1, 1, 2]. Fit: 0.003237392390534903
# Indivíduo: [7, 4, 1, 1, 0]. Fit: 0.002780134535472219
# Elite: [[5, 4, 2, 0, 0], [5, 2, 0, 1, 0]]
# Estado salvo em 'ag_estado.pkl'.
#
# Geração 2
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 2, 0, 0]. Fit: 0.0027188917195114003
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 0, 1, 0]. Fit: 0.002777034396422096
# Indivíduo já avaliado.
# Indivíduo: [6, 2, 0, 2, 1]. Fit: 0.011265923913257817
# Indivíduo: [3, 3, 0, 1, 0]. Fit: 0.0030673791984251386
# Indivíduo: [5, 1, 0, 1, 0]. Fit: 0.0028764718774861348
# Indivíduo: [1, 1, 2, 2, 2]. Fit: 0.006722311594057828
# Indivíduo: [7, 0, 0, 2, 2]. Fit: 0.005693012526414047
# Indivíduo: [3, 4, 1, 2, 1]. Fit: 0.0072592986495389296
# Indivíduo: [9, 4, 1, 0, 0]. Fit: 0.0034241351318390414
# Indivíduo: [10, 4, 1, 2, 2]. Fit: 0.003781925397925079
# Indivíduo: [0, 2, 0, 0, 2]. Fit: 0.0103528251638636
# Indivíduo: [4, 4, 2, 0, 1]. Fit: 0.010031223244732245
# Indivíduo: [11, 4, 0, 0, 2]. Fit: 0.011068073784311613
# Indivíduo: [11, 2, 0, 1, 1]. Fit: 0.007312313678752011
# Indivíduo: [4, 1, 0, 1, 2]. Fit: 0.008397737971972673
# Indivíduo: [6, 0, 0, 2, 1]. Fit: 0.012876726869338504
# Indivíduo já avaliado.
# Indivíduo: [1, 3, 1, 2, 1]. Fit: 0.010832309825733926
# Indivíduo: [1, 4, 2, 0, 1]. Fit: 0.008948971005156636
# Indivíduo: [9, 4, 1, 1, 1]. Fit: 0.00696409745917966
# Indivíduo: [11, 2, 0, 0, 2]. Fit: 0.009166142138807724
# Indivíduo: [4, 4, 0, 0, 2]. Fit: 0.012929591672339785
# Indivíduo: [4, 1, 2, 0, 0]. Fit: 0.006794156386361769
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 1, 1, 1]. Fit: 0.012122677776884907
# Indivíduo: [5, 0, 0, 0, 2]. Fit: 0.005740233008206511
# Indivíduo: [3, 1, 1, 0, 2]. Fit: 0.006374961230903864
# Indivíduo: [10, 3, 2, 2, 1]. Fit: 0.004979960791145762
# Indivíduo: [5, 2, 2, 1, 2]. Fit: 0.0027842088272639854
# Indivíduo: [10, 2, 0, 2, 2]. Fit: 0.004781056178035215
# Indivíduo: [5, 4, 0, 0, 1]. Fit: 0.005290949373738841
# Indivíduo: [6, 1, 0, 2, 2]. Fit: 0.008009328103313843
# Indivíduo: [5, 2, 0, 2, 2]. Fit: 0.004073225735919551
# Indivíduo: [11, 2, 0, 2, 1]. Fit: 0.007477877787702406
# Indivíduo: [3, 3, 1, 1, 0]. Fit: 0.0030702597801185528
# Indivíduo: [1, 2, 0, 0, 0]. Fit: 0.006624609757758057
# Indivíduo: [10, 1, 1, 1, 2]. Fit: 0.0029316603613551706
# Indivíduo: [7, 0, 0, 0, 1]. Fit: 0.007822643008936817
# Indivíduo: [4, 2, 2, 0, 1]. Fit: 0.010570675951506323
# Indivíduo: [1, 4, 1, 2, 1]. Fit: 0.010051075615532076
# Indivíduo já avaliado.
# Indivíduo: [0, 4, 2, 0, 2]. Fit: 0.008073595278741168
# Indivíduo: [11, 2, 2, 1, 2]. Fit: 0.0029618825035868214
# Indivíduo: [5, 0, 1, 1, 0]. Fit: 0.0031114828501207135
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 1, 1, 1]. Fit: 0.012122677776884907
# Indivíduo: [10, 4, 0, 2, 1]. Fit: 0.00662670389865525
# Indivíduo: [10, 1, 0, 2, 1]. Fit: 0.007294224916646878
# Indivíduo: [1, 3, 0, 1, 0]. Fit: 0.006529089307878167
# Indivíduo já avaliado.
# Indivíduo: [9, 3, 0, 0, 0]. Fit: 0.0033737235624964035
# Indivíduo: [4, 4, 2, 0, 0]. Fit: 0.006777911840860422
# Indivíduo: [4, 2, 2, 1, 0]. Fit: 0.006843949747659887
# Indivíduo: [2, 0, 0, 1, 2]. Fit: 0.007215959761136523
# Indivíduo: [0, 4, 1, 2, 1]. Fit: 0.011811562220100314
# Elite: [[5, 4, 2, 0, 0], [5, 2, 0, 1, 0]]
# Estado salvo em 'ag_estado.pkl'.
#
# Geração 3
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 2, 0, 0]. Fit: 0.0027188917195114003
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 0, 1, 0]. Fit: 0.002777034396422096
# Indivíduo: [9, 2, 0, 1, 1]. Fit: 0.008116940327454358
# Indivíduo: [4, 4, 0, 1, 2]. Fit: 0.008312151689703267
# Indivíduo já avaliado.
# Indivíduo: [2, 0, 0, 1, 2]. Fit: 0.007215959761136523
# Indivíduo: [5, 4, 0, 0, 0]. Fit: 0.0029704597128632788
# Indivíduo: [7, 0, 2, 2, 2]. Fit: 0.004210761616316934
# Indivíduo: [1, 3, 1, 0, 0]. Fit: 0.006581477782068153
# Indivíduo: [5, 1, 0, 1, 2]. Fit: 0.0030469737908182045
# Indivíduo já avaliado.
# Indivíduo: [11, 2, 0, 1, 1]. Fit: 0.007312313678752011
# Indivíduo: [4, 1, 2, 1, 0]. Fit: 0.0068327068060170856
# Indivíduo: [6, 1, 0, 2, 1]. Fit: 0.012271011302558085
# Indivíduo: [1, 0, 0, 1, 2]. Fit: 0.007249629726478209
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 0, 1]. Fit: 0.010031223244732245
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 0, 1, 0]. Fit: 0.007348232904526715
# Indivíduo: [0, 4, 0, 1, 0]. Fit: 0.00815526616643183
# Indivíduo: [5, 0, 2, 0, 0]. Fit: 0.002912429164280184
# Indivíduo: [4, 1, 1, 1, 2]. Fit: 0.007819327141623944
# Indivíduo: [1, 0, 1, 0, 2]. Fit: 0.008780856430530549
# Indivíduo: [3, 3, 1, 0, 2]. Fit: 0.00652392800936165
# Indivíduo: [1, 1, 0, 0, 1]. Fit: 0.012013324284149956
# Indivíduo: [10, 1, 1, 1, 1]. Fit: 0.006598671440345547
# Indivíduo já avaliado.
# Indivíduo: [4, 1, 2, 1, 0]. Fit: 0.0068327068060170856
# Indivíduo: [5, 1, 1, 2, 1]. Fit: 0.006905061020127809
# Indivíduo: [9, 4, 1, 0, 1]. Fit: 0.007081322288528706
# Indivíduo: [1, 1, 0, 0, 2]. Fit: 0.01300948695667709
# Indivíduo: [5, 0, 2, 0, 2]. Fit: 0.00419373995779703
# Indivíduo: [10, 4, 1, 1, 1]. Fit: 0.00602259158428448
# Indivíduo: [1, 1, 2, 0, 0]. Fit: 0.006391302895887444
# Indivíduo: [1, 4, 0, 2, 1]. Fit: 0.01044745459027278
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 0, 2, 2]. Fit: 0.003680603006311382
# Indivíduo já avaliado.
# Indivíduo: [11, 2, 0, 2, 1]. Fit: 0.007477877787702406
# Indivíduo: [5, 2, 2, 1, 0]. Fit: 0.0026318963510372365
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 1, 1, 1]. Fit: 0.012122677776884907
# Indivíduo: [5, 1, 0, 2, 1]. Fit: 0.00730036932315367
# Indivíduo: [3, 4, 1, 1, 1]. Fit: 0.007065729044067363
# Indivíduo: [6, 3, 2, 0, 0]. Fit: 0.006591253054405872
# Indivíduo: [1, 1, 2, 0, 1]. Fit: 0.010653857296953598
# Indivíduo: [3, 3, 0, 0, 2]. Fit: 0.008464840702557314
# Indivíduo: [6, 2, 2, 2, 0]. Fit: 0.006488963243706772
# Indivíduo: [5, 4, 2, 2, 0]. Fit: 0.003886348214776566
# Indivíduo: [6, 4, 0, 0, 1]. Fit: 0.009686536695032071
# Indivíduo: [6, 2, 0, 1, 1]. Fit: 0.010828955789717534
# Indivíduo já avaliado.
# Indivíduo: [1, 3, 0, 1, 0]. Fit: 0.006529089307878167
# Indivíduo: [1, 4, 1, 0, 0]. Fit: 0.00642857279938956
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 2, 0, 0]. Fit: 0.0027188917195114003
# Indivíduo: [3, 2, 2, 0, 1]. Fit: 0.005701449660894771
# Indivíduo já avaliado.
# Indivíduo: [11, 2, 0, 0, 2]. Fit: 0.009166142138807724
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 0, 2, 2]. Fit: 0.004073225735919551
# Indivíduo: [10, 0, 0, 2, 2]. Fit: 0.005126706421530495
# Elite: [[5, 2, 2, 1, 0], [5, 4, 2, 0, 0]]
# Estado salvo em 'ag_estado.pkl'.
#
# Geração 4
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 2, 1, 0]. Fit: 0.0026318963510372365
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 2, 0, 0]. Fit: 0.0027188917195114003
# Indivíduo: [10, 2, 2, 1, 0]. Fit: 0.002858135793940164
# Indivíduo: [5, 4, 0, 1, 0]. Fit: 0.002649206403293647
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 2, 0, 0]. Fit: 0.0027188917195114003
# Indivíduo: [11, 4, 0, 0, 0]. Fit: 0.0032798884970058374
# Indivíduo: [3, 2, 2, 0, 0]. Fit: 0.0032266115808549023
# Indivíduo: [1, 3, 2, 1, 0]. Fit: 0.006122137538235014
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 1, 0]. Fit: 0.002649206403293647
# Indivíduo já avaliado.
# Indivíduo: [5, 0, 2, 0, 0]. Fit: 0.002912429164280184
# Indivíduo: [5, 4, 0, 2, 1]. Fit: 0.006683274608803913
# Indivíduo: [2, 0, 0, 1, 1]. Fit: 0.012641980526192734
# Indivíduo: [3, 4, 0, 2, 2]. Fit: 0.004479263780134109
# Indivíduo: [1, 4, 0, 1, 1]. Fit: 0.010663897957419977
# Indivíduo já avaliado.
# Indivíduo: [10, 2, 0, 2, 2]. Fit: 0.004781056178035215
# Indivíduo: [10, 4, 1, 0, 1]. Fit: 0.005835343971072385
# Indivíduo: [0, 4, 2, 1, 0]. Fit: 0.00707419408718124
# Indivíduo: [4, 2, 1, 1, 2]. Fit: 0.007582470239140093
# Indivíduo: [1, 4, 2, 2, 0]. Fit: 0.006519436599531521
# Indivíduo: [4, 1, 1, 1, 1]. Fit: 0.013420776828813059
# Indivíduo: [1, 3, 0, 2, 0]. Fit: 0.006373984186211601
# Indivíduo: [5, 1, 0, 2, 0]. Fit: 0.0040456709500479825
# Indivíduo: [10, 4, 0, 1, 1]. Fit: 0.006580757821211591
# Indivíduo: [5, 0, 2, 2, 0]. Fit: 0.004111551033565775
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 1, 2]. Fit: 0.006887000826342653
# Indivíduo: [1, 4, 0, 1, 2]. Fit: 0.007119150836175927
# Indivíduo: [11, 4, 2, 0, 1]. Fit: 0.005263042636215687
# Indivíduo: [1, 1, 2, 0, 2]. Fit: 0.009326170082204044
# Indivíduo: [3, 2, 1, 1, 1]. Fit: 0.007448310102336109
# Indivíduo: [3, 4, 0, 1, 1]. Fit: 0.008032478970320275
# Indivíduo: [11, 4, 1, 0, 1]. Fit: 0.006546517641982064
# Indivíduo: [5, 0, 2, 1, 1]. Fit: 0.006443210508829604
# Indivíduo: [1, 0, 1, 1, 2]. Fit: 0.0069848160240023075
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 0, 2, 0]. Fit: 0.0033393092880335947
# Indivíduo: [1, 3, 0, 0, 2]. Fit: 0.01753951087594032
# Indivíduo: [10, 0, 1, 2, 1]. Fit: 0.0071618151618167755
# Indivíduo: [4, 3, 2, 0, 0]. Fit: 0.006686487153638154
# Indivíduo: [3, 3, 0, 0, 1]. Fit: 0.007471216539852321
# Indivíduo: [5, 1, 0, 0, 2]. Fit: 0.013077893011116731
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 0, 1, 2]. Fit: 0.008312151689703267
# Indivíduo já avaliado.
# Indivíduo: [1, 1, 0, 0, 1]. Fit: 0.012013324284149956
# Indivíduo já avaliado.
# Indivíduo: [1, 1, 2, 0, 0]. Fit: 0.006391302895887444
# Indivíduo: [3, 4, 1, 0, 1]. Fit: 0.007160312311801438
# Indivíduo: [1, 4, 0, 0, 2]. Fit: 0.019107150410612422
# Indivíduo: [5, 0, 2, 1, 0]. Fit: 0.003132625400515584
# Indivíduo: [1, 3, 0, 2, 1]. Fit: 0.010869214493626107
# Indivíduo: [0, 4, 0, 2, 0]. Fit: 0.007670706322339053
# Indivíduo: [6, 4, 2, 0, 1]. Fit: 0.008911581209395081
# Indivíduo: [5, 2, 2, 1, 1]. Fit: 0.005714376845086615
# Indivíduo: [5, 1, 1, 2, 2]. Fit: 0.004443401682268208
# Elite: [[5, 2, 2, 1, 0], [5, 4, 0, 1, 0]]
# Estado salvo em 'ag_estado.pkl'.
#
# Geração 5
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 2, 1, 0]. Fit: 0.0026318963510372365
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 1, 0]. Fit: 0.002649206403293647
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 1, 0, 1]. Fit: 0.005835343971072385
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 0, 1, 1]. Fit: 0.010663897957419977
# Indivíduo: [5, 3, 0, 0, 0]. Fit: 0.0029648820481573543
# Indivíduo: [1, 0, 2, 2, 2]. Fit: 0.0069451516300129395
# Indivíduo: [1, 0, 2, 2, 0]. Fit: 0.006870071002049371
# Indivíduo: [4, 2, 2, 2, 0]. Fit: 0.007612424671727543
# Indivíduo: [7, 4, 2, 1, 1]. Fit: 0.005163347761845216
# Indivíduo: [3, 2, 0, 1, 2]. Fit: 0.003333154666082313
# Indivíduo: [10, 1, 2, 0, 2]. Fit: 0.0067128562252037225
# Indivíduo: [10, 2, 1, 2, 2]. Fit: 0.0038731946260668337
# Indivíduo: [4, 1, 1, 2, 0]. Fit: 0.008157962812886884
# Indivíduo: [1, 4, 0, 1, 0]. Fit: 0.006501345099726071
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 2, 1]. Fit: 0.006683274608803913
# Indivíduo: [1, 1, 1, 1, 2]. Fit: 0.007045421384585401
# Indivíduo já avaliado.
# Indivíduo: [3, 4, 0, 1, 1]. Fit: 0.008032478970320275
# Indivíduo: [5, 4, 2, 2, 1]. Fit: 0.0053060942116038255
# Indivíduo: [1, 0, 2, 1, 0]. Fit: 0.0063371804581644625
# Indivíduo: [4, 2, 2, 1, 2]. Fit: 0.006923154696899777
# Indivíduo: [4, 3, 0, 0, 0]. Fit: 0.006767612672410906
# Indivíduo já avaliado.
# Indivíduo: [1, 1, 0, 0, 2]. Fit: 0.01300948695667709
# Indivíduo: [5, 4, 1, 0, 2]. Fit: 0.01582614512493213
# Indivíduo: [5, 3, 2, 0, 0]. Fit: 0.002808986327727325
# Indivíduo: [5, 2, 2, 2, 0]. Fit: 0.003946164921702196
# Indivíduo: [4, 0, 1, 1, 2]. Fit: 0.007817472319584339
# Indivíduo já avaliado.
# Indivíduo: [5, 1, 0, 2, 1]. Fit: 0.00730036932315367
# Indivíduo: [9, 4, 2, 2, 0]. Fit: 0.0046176356826132785
# Indivíduo: [1, 1, 2, 1, 0]. Fit: 0.006179780627523238
# Indivíduo: [10, 1, 0, 0, 2]. Fit: 0.012788767790577065
# Indivíduo: [1, 0, 2, 2, 1]. Fit: 0.011901446113673348
# Indivíduo: [1, 4, 1, 2, 2]. Fit: 0.006373757077381015
# Indivíduo: [11, 0, 2, 0, 1]. Fit: 0.005972987091323982
# Indivíduo: [10, 2, 0, 1, 0]. Fit: 0.002809755273240929
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 1, 2]. Fit: 0.006887000826342653
# Indivíduo: [1, 4, 1, 1, 1]. Fit: 0.01039768949073429
# Indivíduo: [4, 1, 2, 2, 1]. Fit: 0.011514192582884183
# Indivíduo: [0, 4, 0, 1, 2]. Fit: 0.008625545888207851
# Indivíduo: [2, 4, 2, 1, 1]. Fit: 0.008607123555460325
# Indivíduo: [5, 0, 0, 0, 1]. Fit: 0.008246565916730711
# Indivíduo: [3, 2, 0, 0, 1]. Fit: 0.00840394952101633
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 1, 0, 1]. Fit: 0.005835343971072385
# Indivíduo: [2, 0, 0, 0, 0]. Fit: 0.0067099765680419905
# Indivíduo: [5, 4, 0, 1, 1]. Fit: 0.006670685721716532
# Indivíduo: [11, 3, 0, 0, 0]. Fit: 0.0031801400240510703
# Indivíduo: [1, 3, 0, 1, 1]. Fit: 0.011076829112910976
# Indivíduo: [11, 4, 2, 0, 0]. Fit: 0.003114172080919767
# Indivíduo: [10, 4, 0, 1, 0]. Fit: 0.0027376971459792307
# Indivíduo: [3, 1, 0, 1, 2]. Fit: 0.0033468165434896945
# Indivíduo: [1, 3, 2, 2, 1]. Fit: 0.009337321276931713
# Elite: [[5, 2, 2, 1, 0], [5, 4, 0, 1, 0]]
# Estado salvo em 'ag_estado.pkl'.
#
# Geração 6
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 2, 1, 0]. Fit: 0.0026318963510372365
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 1, 0]. Fit: 0.002649206403293647
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 2, 2, 0]. Fit: 0.007612424671727543
# Indivíduo: [1, 4, 1, 0, 1]. Fit: 0.010132424562470986
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 1, 1]. Fit: 0.006670685721716532
# Indivíduo: [10, 1, 1, 0, 1]. Fit: 0.006719633195704471
# Indivíduo: [7, 3, 0, 1, 1]. Fit: 0.007254086215592299
# Indivíduo: [0, 4, 2, 2, 2]. Fit: 0.008275403972947971
# Indivíduo: [1, 2, 0, 1, 0]. Fit: 0.006528325177108248
# Indivíduo: [1, 3, 0, 2, 2]. Fit: 0.006766590726329014
# Indivíduo: [7, 1, 1, 2, 1]. Fit: 0.006847909496476253
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 0, 2, 2]. Fit: 0.004073225735919551
# Indivíduo: [0, 0, 2, 1, 0]. Fit: 0.007231034165791546
# Indivíduo: [1, 4, 1, 1, 2]. Fit: 0.007023076586968576
# Indivíduo: [4, 1, 1, 2, 2]. Fit: 0.007995505943351116
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 2, 2, 0]. Fit: 0.007612424671727543
# Indivíduo: [1, 1, 0, 0, 0]. Fit: 0.006570107819667707
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 1, 0]. Fit: 0.002649206403293647
# Indivíduo: [10, 2, 1, 0, 1]. Fit: 0.006230200625335177
# Indivíduo já avaliado.
# Indivíduo: [5, 1, 0, 1, 0]. Fit: 0.0028764718774861348
# Indivíduo já avaliado.
# Indivíduo: [1, 1, 0, 0, 0]. Fit: 0.006570107819667707
# Indivíduo: [10, 3, 2, 0, 0]. Fit: 0.003035168991967415
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 0, 1]. Fit: 0.005290949373738841
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 1, 2]. Fit: 0.006887000826342653
# Indivíduo: [4, 4, 1, 1, 1]. Fit: 0.01157509867528764
# Indivíduo: [5, 3, 0, 1, 0]. Fit: 0.002684298299330597
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 2, 0, 0]. Fit: 0.0027188917195114003
# Indivíduo já avaliado.
# Indivíduo: [3, 2, 0, 1, 2]. Fit: 0.003333154666082313
# Indivíduo: [10, 4, 2, 1, 1]. Fit: 0.0049310001040187975
# Indivíduo: [10, 2, 0, 0, 2]. Fit: 0.016407944347398975
# Indivíduo: [2, 4, 2, 1, 2]. Fit: 0.006370915301765005
# Indivíduo: [1, 0, 0, 2, 2]. Fit: 0.008355000036923837
# Indivíduo: [3, 3, 2, 1, 0]. Fit: 0.00310961029608734
# Indivíduo: [2, 2, 1, 0, 2]. Fit: 0.009388565229407201
# Indivíduo: [2, 4, 2, 0, 0]. Fit: 0.006309421319747344
# Indivíduo: [1, 0, 1, 1, 0]. Fit: 0.006627769050343584
# Indivíduo: [4, 4, 0, 1, 1]. Fit: 0.012549644448639203
# Indivíduo: [4, 3, 0, 1, 2]. Fit: 0.008392690991361935
# Indivíduo: [4, 0, 2, 2, 1]. Fit: 0.012621154938824476
# Indivíduo: [1, 3, 2, 2, 2]. Fit: 0.0065581211897855
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 0, 1]. Fit: 0.005290949373738841
# Indivíduo: [4, 2, 2, 0, 0]. Fit: 0.006818840904937435
# Indivíduo: [3, 1, 2, 2, 2]. Fit: 0.005041025761359682
# Indivíduo: [1, 2, 2, 2, 2]. Fit: 0.006608913999904567
# Indivíduo: [1, 1, 2, 2, 1]. Fit: 0.010438681339534621
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 0, 1, 1]. Fit: 0.010663897957419977
# Indivíduo: [4, 2, 2, 2, 1]. Fit: 0.010540127758091936
# Indivíduo: [10, 4, 2, 0, 0]. Fit: 0.003115577237137283
# Indivíduo: [5, 4, 1, 1, 1]. Fit: 0.006247872112241263
# Indivíduo: [5, 3, 0, 2, 1]. Fit: 0.006931594497291371
# Elite: [[5, 2, 2, 1, 0], [5, 4, 0, 1, 0]]
# Estado salvo em 'ag_estado.pkl'.
#
# Geração 7
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 2, 1, 0]. Fit: 0.0026318963510372365
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 1, 0]. Fit: 0.002649206403293647
# Indivíduo: [7, 1, 0, 1, 0]. Fit: 0.002857724679051898
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 2, 0, 1]. Fit: 0.008948971005156636
# Indivíduo: [0, 2, 2, 0, 0]. Fit: 0.006884913051423307
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 1, 0, 1]. Fit: 0.010132424562470986
# Indivíduo: [1, 2, 1, 0, 0]. Fit: 0.006592180331548054
# Indivíduo: [4, 4, 2, 2, 2]. Fit: 0.007545977473879854
# Indivíduo já avaliado.
# Indivíduo: [4, 1, 2, 0, 0]. Fit: 0.006794156386361769
# Indivíduo: [5, 4, 0, 0, 2]. Fit: 0.01915820954212298
# Indivíduo: [0, 4, 2, 0, 1]. Fit: 0.009949058847269043
# Indivíduo: [3, 3, 1, 1, 1]. Fit: 0.007292658146858836
# Indivíduo: [1, 0, 2, 1, 1]. Fit: 0.011833356860248995
# Indivíduo: [4, 1, 2, 1, 1]. Fit: 0.0114174860684822
# Indivíduo: [7, 1, 1, 1, 1]. Fit: 0.007048973542017241
# Indivíduo: [3, 4, 2, 1, 0]. Fit: 0.0031928664238269748
# Indivíduo: [5, 2, 0, 1, 1]. Fit: 0.00713929661239187
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 1, 1, 1]. Fit: 0.01039768949073429
# Indivíduo já avaliado.
# Indivíduo: [5, 1, 0, 2, 1]. Fit: 0.00730036932315367
# Indivíduo: [4, 4, 1, 1, 2]. Fit: 0.007643316963609928
# Indivíduo: [1, 2, 2, 0, 2]. Fit: 0.010663244295089195
# Indivíduo: [1, 0, 2, 1, 2]. Fit: 0.006364248993728931
# Indivíduo: [4, 2, 1, 2, 1]. Fit: 0.012645894502444816
# Indivíduo: [10, 2, 1, 0, 2]. Fit: 0.014386116185535988
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 1, 0, 1]. Fit: 0.005835343971072385
# Indivíduo: [4, 4, 2, 1, 1]. Fit: 0.009746142474856848
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 1, 1, 1]. Fit: 0.01157509867528764
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 1, 1]. Fit: 0.006670685721716532
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 0, 1, 2]. Fit: 0.008312151689703267
# Indivíduo: [2, 1, 0, 0, 2]. Fit: 0.009585412741095447
# Indivíduo: [10, 4, 2, 0, 2]. Fit: 0.011810097111932313
# Indivíduo: [10, 3, 2, 0, 1]. Fit: 0.004900154787659024
# Indivíduo já avaliado.
# Indivíduo: [4, 1, 2, 2, 1]. Fit: 0.011514192582884183
# Indivíduo: [4, 1, 0, 1, 0]. Fit: 0.007459546222041051
# Indivíduo: [1, 3, 2, 0, 2]. Fit: 0.010572008811868726
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 2, 0, 2]. Fit: 0.011810097111932313
# Indivíduo: [3, 2, 0, 0, 0]. Fit: 0.003376859517690415
# Indivíduo: [10, 4, 2, 0, 1]. Fit: 0.004949433502042667
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 1, 1, 1]. Fit: 0.006247872112241263
# Indivíduo: [5, 4, 0, 1, 2]. Fit: 0.0030162134557031096
# Indivíduo: [7, 2, 1, 0, 2]. Fit: 0.00686048908974044
# Indivíduo: [5, 3, 2, 0, 1]. Fit: 0.005432072658247003
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 1, 0, 0]. Fit: 0.00642857279938956
# Indivíduo: [7, 4, 0, 1, 2]. Fit: 0.0028992039811176562
# Indivíduo já avaliado.
# Indivíduo: [2, 4, 2, 0, 0]. Fit: 0.006309421319747344
# Indivíduo já avaliado.
# Indivíduo: [4, 0, 2, 2, 1]. Fit: 0.012621154938824476
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 0, 0]. Fit: 0.006777911840860422
# Indivíduo: [4, 1, 2, 2, 2]. Fit: 0.007832043022305396
# Indivíduo: [2, 4, 2, 0, 2]. Fit: 0.007062622768959652
# Indivíduo já avaliado.
# Indivíduo: [5, 1, 0, 2, 0]. Fit: 0.0040456709500479825
# Elite: [[5, 2, 2, 1, 0], [5, 4, 0, 1, 0]]
# Estado salvo em 'ag_estado.pkl'.
#
# Geração 8
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 2, 1, 0]. Fit: 0.0026318963510372365
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 1, 0]. Fit: 0.002649206403293647
# Indivíduo: [2, 3, 1, 0, 1]. Fit: 0.010661200953957933
# Indivíduo: [5, 1, 0, 1, 1]. Fit: 0.0072570400273737805
# Indivíduo já avaliado.
# Indivíduo: [1, 0, 1, 0, 2]. Fit: 0.008780856430530549
# Indivíduo: [7, 2, 0, 2, 0]. Fit: 0.004272362692669655
# Indivíduo: [4, 2, 0, 1, 1]. Fit: 0.012955917629490919
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 0, 2, 1]. Fit: 0.01044745459027278
# Indivíduo: [1, 2, 1, 0, 2]. Fit: 0.01554733676215013
# Indivíduo: [3, 4, 2, 1, 2]. Fit: 0.0037477660768975816
# Indivíduo: [6, 2, 2, 0, 2]. Fit: 0.01129479504500826
# Indivíduo: [7, 2, 1, 1, 1]. Fit: 0.006690503162099048
# Indivíduo já avaliado.
# Indivíduo: [4, 0, 2, 0, 1]. Fit: 0.010757560151008268
# Indivíduo: [5, 4, 2, 0, 1]. Fit: 0.0053253479670577995
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 2, 2, 1]. Fit: 0.010540127758091936
# Indivíduo: [4, 3, 2, 1, 1]. Fit: 0.010112057040290286
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 1, 1, 1]. Fit: 0.01039768949073429
# Indivíduo já avaliado.
# Indivíduo: [1, 0, 2, 2, 0]. Fit: 0.006870071002049371
# Indivíduo já avaliado.
# Indivíduo: [2, 1, 0, 0, 2]. Fit: 0.009585412741095447
# Indivíduo: [5, 1, 0, 0, 1]. Fit: 0.007380144624039531
# Indivíduo: [1, 3, 1, 0, 2]. Fit: 0.01609787792743494
# Indivíduo já avaliado.
# Indivíduo: [4, 1, 2, 0, 0]. Fit: 0.006794156386361769
# Indivíduo: [10, 4, 0, 0, 2]. Fit: 0.02288035376307865
# Indivíduo: [7, 3, 2, 0, 2]. Fit: 0.0035302004757492497
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 2, 1, 0]. Fit: 0.006843949747659887
# Indivíduo já avaliado.
# Indivíduo: [10, 2, 1, 0, 2]. Fit: 0.014386116185535988
# Indivíduo: [5, 1, 2, 2, 1]. Fit: 0.005837823731902366
# Indivíduo: [8, 4, 2, 0, 1]. Fit: 0.009175624217217168
# Indivíduo já avaliado.
# Indivíduo: [2, 4, 2, 0, 0]. Fit: 0.006309421319747344
# Indivíduo: [7, 1, 1, 0, 0]. Fit: 0.0028932255091300855
# Indivíduo já avaliado.
# Indivíduo: [1, 0, 2, 2, 0]. Fit: 0.006870071002049371
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 0, 1, 0]. Fit: 0.002649206403293647
# Indivíduo: [4, 4, 1, 0, 0]. Fit: 0.006646296676869194
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 2, 0, 1]. Fit: 0.004949433502042667
# Indivíduo já avaliado.
# Indivíduo: [1, 0, 2, 1, 2]. Fit: 0.006364248993728931
# Indivíduo já avaliado.
# Indivíduo: [2, 3, 1, 0, 1]. Fit: 0.010661200953957933
# Indivíduo: [1, 2, 0, 0, 1]. Fit: 0.010832572057067107
# Indivíduo: [7, 1, 0, 1, 1]. Fit: 0.007294094030900547
# Indivíduo: [7, 1, 2, 1, 2]. Fit: 0.0028898689721245318
# Indivíduo: [5, 4, 2, 1, 1]. Fit: 0.005355362805615489
# Indivíduo: [5, 2, 1, 1, 2]. Fit: 0.0028008840172939623
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 1, 1, 1]. Fit: 0.00602259158428448
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 1, 0, 0]. Fit: 0.002882710523166073
# Indivíduo: [7, 0, 2, 1, 2]. Fit: 0.003082546014532757
# Indivíduo já avaliado.
# Indivíduo: [1, 2, 1, 0, 2]. Fit: 0.01554733676215013
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 0, 1]. Fit: 0.010031223244732245
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 0, 0, 2]. Fit: 0.019107150410612422
# Indivíduo: [1, 3, 1, 1, 1]. Fit: 0.010754569222141679
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 2, 0, 1]. Fit: 0.004949433502042667
# Indivíduo: [5, 4, 2, 1, 0]. Fit: 0.0026254405587678776
# Elite: [[5, 4, 2, 1, 0], [5, 2, 2, 1, 0]]
# Estado salvo em 'ag_estado.pkl'.
#
# Geração 9
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 2, 1, 0]. Fit: 0.0026254405587678776
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 2, 1, 0]. Fit: 0.0026318963510372365
# Indivíduo: [8, 4, 2, 2, 0]. Fit: 0.006877027863326173
# Indivíduo: [4, 0, 2, 1, 1]. Fit: 0.012140377300481
# Indivíduo: [5, 2, 2, 0, 0]. Fit: 0.002791516959162739
# Indivíduo: [2, 2, 1, 0, 1]. Fit: 0.011437851512649408
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 0, 1]. Fit: 0.010031223244732245
# Indivíduo: [5, 4, 1, 1, 0]. Fit: 0.002654908687691204
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 2, 1, 1]. Fit: 0.0049310001040187975
# Indivíduo: [7, 1, 2, 0, 1]. Fit: 0.0054248084255959835
# Indivíduo: [5, 2, 1, 1, 1]. Fit: 0.006367015357439716
# Indivíduo já avaliado.
# Indivíduo: [5, 1, 0, 1, 1]. Fit: 0.0072570400273737805
# Indivíduo: [4, 1, 2, 0, 2]. Fit: 0.007989272226889929
# Indivíduo: [8, 1, 2, 2, 1]. Fit: 0.011082471162080764
# Indivíduo: [3, 4, 2, 0, 2]. Fit: 0.004244612042869751
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 0, 1]. Fit: 0.010031223244732245
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 1, 1, 1]. Fit: 0.006247872112241263
# Indivíduo: [5, 2, 0, 1, 2]. Fit: 0.0030529322869066768
# Indivíduo: [7, 2, 0, 1, 1]. Fit: 0.007339646727389966
# Indivíduo já avaliado.
# Indivíduo: [10, 2, 1, 0, 2]. Fit: 0.014386116185535988
# Indivíduo: [1, 2, 1, 1, 0]. Fit: 0.006260499348475908
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 1, 0, 0]. Fit: 0.002882710523166073
# Indivíduo: [1, 4, 1, 1, 0]. Fit: 0.006183333079873895
# Indivíduo: [2, 3, 1, 1, 1]. Fit: 0.010791648887485888
# Indivíduo já avaliado.
# Indivíduo: [1, 0, 2, 2, 1]. Fit: 0.011901446113673348
# Indivíduo já avaliado.
# Indivíduo: [4, 0, 2, 2, 1]. Fit: 0.012621154938824476
# Indivíduo já avaliado.
# Indivíduo: [5, 1, 0, 1, 0]. Fit: 0.0028764718774861348
# Indivíduo: [4, 1, 1, 0, 1]. Fit: 0.013033571672470618
# Indivíduo: [4, 4, 2, 1, 0]. Fit: 0.0067797901380496715
# Indivíduo já avaliado.
# Indivíduo: [4, 1, 2, 0, 0]. Fit: 0.006794156386361769
# Indivíduo: [1, 2, 1, 0, 1]. Fit: 0.01082469296331207
# Indivíduo já avaliado.
# Indivíduo: [10, 1, 1, 1, 1]. Fit: 0.006598671440345547
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 0, 1, 1]. Fit: 0.010663897957419977
# Indivíduo já avaliado.
# Indivíduo: [1, 2, 2, 0, 2]. Fit: 0.010663244295089195
# Indivíduo: [1, 0, 2, 0, 0]. Fit: 0.006599217529098192
# Indivíduo já avaliado.
# Indivíduo: [10, 2, 1, 0, 1]. Fit: 0.006230200625335177
# Indivíduo: [1, 1, 0, 1, 1]. Fit: 0.01173039119457826
# Indivíduo já avaliado.
# Indivíduo: [2, 3, 1, 0, 1]. Fit: 0.010661200953957933
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 2, 0, 0]. Fit: 0.006818840904937435
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 0, 1, 0]. Fit: 0.006501345099726071
# Indivíduo: [5, 2, 1, 0, 2]. Fit: 0.013364728280187893
# Indivíduo já avaliado.
# Indivíduo: [1, 2, 0, 0, 1]. Fit: 0.010832572057067107
# Indivíduo: [1, 2, 2, 2, 0]. Fit: 0.006588977356053268
# Indivíduo: [7, 0, 2, 0, 1]. Fit: 0.005518738987545173
# Indivíduo: [2, 2, 2, 0, 2]. Fit: 0.007445726396205524
# Indivíduo: [5, 1, 1, 0, 2]. Fit: 0.010044784739147872
# Indivíduo: [8, 1, 1, 0, 0]. Fit: 0.006541818017528083
# Indivíduo: [2, 2, 2, 0, 0]. Fit: 0.006377336939719196
# Indivíduo: [7, 4, 1, 0, 0]. Fit: 0.0028350901731755583
# Indivíduo já avaliado.
# Indivíduo: [1, 2, 2, 0, 2]. Fit: 0.010663244295089195
# Elite: [[5, 4, 2, 1, 0], [5, 2, 2, 1, 0]]
# Estado salvo em 'ag_estado.pkl'.
#
# Geração 10
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 2, 1, 0]. Fit: 0.0026254405587678776
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 2, 1, 0]. Fit: 0.0026318963510372365
# Indivíduo: [4, 4, 1, 1, 0]. Fit: 0.006884996721055359
# Indivíduo: [5, 2, 0, 0, 1]. Fit: 0.006561939847112322
# Indivíduo: [7, 2, 2, 1, 1]. Fit: 0.00534876777868097
# Indivíduo: [7, 4, 2, 0, 0]. Fit: 0.0026813870683933295
# Indivíduo: [5, 2, 1, 1, 0]. Fit: 0.0027477712739103783
# Indivíduo: [1, 2, 2, 0, 1]. Fit: 0.010022214066702872
# Indivíduo: [2, 0, 2, 0, 1]. Fit: 0.009879174172723045
# Indivíduo já avaliado.
# Indivíduo: [1, 0, 2, 0, 0]. Fit: 0.006599217529098192
# Indivíduo: [1, 4, 2, 1, 2]. Fit: 0.006235271377954632
# Indivíduo já avaliado.
# Indivíduo: [5, 2, 2, 1, 1]. Fit: 0.005714376845086615
# Indivíduo: [10, 2, 0, 0, 1]. Fit: 0.006231048262755697
# Indivíduo já avaliado.
# Indivíduo: [2, 2, 1, 0, 2]. Fit: 0.009388565229407201
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 0, 0]. Fit: 0.006777911840860422
# Indivíduo: [8, 4, 2, 0, 0]. Fit: 0.0065926612044374154
# Indivíduo: [1, 2, 2, 2, 1]. Fit: 0.009792810453412433
# Indivíduo: [4, 0, 2, 0, 2]. Fit: 0.008174077223520728
# Indivíduo: [1, 2, 2, 1, 1]. Fit: 0.009673865364554026
# Indivíduo já avaliado.
# Indivíduo: [10, 1, 1, 0, 1]. Fit: 0.006719633195704471
# Indivíduo já avaliado.
# Indivíduo: [5, 3, 2, 0, 0]. Fit: 0.002808986327727325
# Indivíduo já avaliado.
# Indivíduo: [10, 4, 1, 0, 1]. Fit: 0.005835343971072385
# Indivíduo: [4, 1, 1, 0, 0]. Fit: 0.006669787866606688
# Indivíduo: [1, 1, 1, 0, 1]. Fit: 0.011217815052562703
# Indivíduo: [1, 4, 0, 0, 1]. Fit: 0.00985911288880743
# Indivíduo já avaliado.
# Indivíduo: [5, 4, 2, 1, 0]. Fit: 0.0026254405587678776
# Indivíduo: [2, 1, 2, 0, 1]. Fit: 0.009364801100067174
# Indivíduo já avaliado.
# Indivíduo: [1, 2, 2, 0, 1]. Fit: 0.010022214066702872
# Indivíduo já avaliado.
# Indivíduo: [1, 2, 1, 0, 1]. Fit: 0.01082469296331207
# Indivíduo: [8, 4, 1, 2, 0]. Fit: 0.006642366355905929
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 0, 0]. Fit: 0.006777911840860422
# Indivíduo já avaliado.
# Indivíduo: [4, 2, 2, 0, 1]. Fit: 0.010570675951506323
# Indivíduo: [8, 4, 2, 0, 2]. Fit: 0.008168938505696133
# Indivíduo: [5, 1, 2, 1, 0]. Fit: 0.002831933382549323
# Indivíduo: [8, 4, 1, 0, 0]. Fit: 0.0066525012933804336
# Indivíduo: [5, 0, 1, 0, 1]. Fit: 0.007314212428173051
# Indivíduo já avaliado.
# Indivíduo: [10, 1, 1, 1, 1]. Fit: 0.006598671440345547
# Indivíduo: [3, 4, 2, 0, 1]. Fit: 0.005836259274898718
# Indivíduo: [2, 2, 2, 1, 0]. Fit: 0.006391862808959559
# Indivíduo já avaliado.
# Indivíduo: [4, 1, 1, 1, 1]. Fit: 0.013420776828813059
# Indivíduo já avaliado.
# Indivíduo: [1, 4, 1, 1, 1]. Fit: 0.01039768949073429
# Indivíduo já avaliado.
# Indivíduo: [10, 2, 1, 0, 2]. Fit: 0.014386116185535988
# Indivíduo: [10, 1, 2, 1, 0]. Fit: 0.0028713678349352755
# Indivíduo: [1, 2, 2, 0, 0]. Fit: 0.006377483731678997
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 2, 0, 0]. Fit: 0.006777911840860422
# Indivíduo já avaliado.
# Indivíduo: [4, 4, 1, 1, 0]. Fit: 0.006884996721055359
# Indivíduo já avaliado.
# Indivíduo: [1, 0, 2, 2, 2]. Fit: 0.0069451516300129395
# Indivíduo já avaliado.
# Indivíduo: [2, 3, 1, 1, 1]. Fit: 0.010791648887485888
# Indivíduo já avaliado.
# Indivíduo: [1, 2, 2, 2, 1]. Fit: 0.009792810453412433
# Indivíduo já avaliado.
# Indivíduo: [4, 0, 2, 0, 1]. Fit: 0.010757560151008268
# Elite: [[5, 4, 2, 1, 0], [5, 4, 2, 1, 0]]
# Estado salvo em 'ag_estado.pkl'.

# %%
modelo_entrada, n_neuronios, ano_entrada, taxa_aprendizado, otm = busca_entrada.populacao[0]
lista_modelo_entrada = (
        [f"M1_{i}" for i in range(1, 2)] +
        [f"M2_{i}" for i in range(1, 5)] +
        [f"M3_{i}" for i in range(1, 6)] + 
        [f"M4_{i}" for i in range(1, 3)]
)
lista_modelo_n_entradas = [48, 48+24, 48+3, 48+2, 48+2, 48+24+2, 48+24+2, 48+3+2, 48+3+2, 48+2+2, 48+24+2+2, 48+3+2+2]
n_entradas = lista_modelo_n_entradas[modelo_entrada]
modelo_entrada = lista_modelo_entrada[modelo_entrada]

lista_n_neuronios = [24, round(0.25*(2*n_entradas-24)+24), round(0.5*(2*n_entradas-24)+24), round(0.75*(2*n_entradas-24)+24), 2*n_entradas]
n_neuronios = lista_n_neuronios[n_neuronios]

lista_ano_entrada = [2018, 2020, 2022]
ano_entrada = lista_ano_entrada[ano_entrada]

lista_taxa_aprendizado = [0.01, 0.001, 0.0001]
taxa_aprendizado = lista_taxa_aprendizado[taxa_aprendizado]

lista_otm = ['Adam', 'Rprop', 'RMSprop']
otm = lista_otm[otm]

print(f'O melhor modelo é: {modelo_entrada}, {n_neuronios}, {ano_entrada}, {taxa_aprendizado}, {otm}')
# Out:
# O melhor modelo é: M3_1, 148, 2022, 0.001, Adam
